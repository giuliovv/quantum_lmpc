# %% [markdown]
# # Duckietown LMPC vs Quantum-Augmented LMPC
#
# This notebook runs the comparison script in this repo.
#
# - Baseline: LMPC using the existing safe-set logic.
# - Quantum: augments the safe set between iterations using Grover-biased sampling (simulated).

# %%
# !python3 -m duckrace.lmpc.duckietown_compare --iterations 5

# %%
# !python3 -m duckrace.lmpc.duckietown_compare --iterations 5 --quantum --quantum-backend statevector --plot --plot-out assets/lmpc_compare.png --diagnostics

# %%
from IPython.display import Image, display
display(Image(filename='assets/lmpc_compare.png'))
